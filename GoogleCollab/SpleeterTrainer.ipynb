# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.

# %%
pip install ffmpeg-python

# %%
# %cd /content/gdrive/My Drive/GoogleCollab/SpleeterTF2.0/SpleeterTF2.0_Unofficial
# Out:
# /content/gdrive/My Drive/GoogleCollab/SpleeterTF2.0/SpleeterTF2.0_Unofficial

# %%
import SpleeterTrain

# %%
SpleeterTrain.trainModel(5001, 1000)
# Out:
# Streaming output truncated to the last 5000 lines.
# took 0.04658 minutes
# [INFO] test loss: 0.6992
# [INFO] Run Step number is 2731
# took 0.04619 minutes
# [INFO] Run Step number is 2732
# took 0.04601 minutes
# [INFO] Run Step number is 2733
# took 0.0457 minutes
# [INFO] Run Step number is 2734
# took 0.04606 minutes
# [INFO] Run Step number is 2735
# took 0.04671 minutes
# [INFO] test loss: 0.6992
# [INFO] Run Step number is 2736
# took 0.04571 minutes
# [INFO] Run Step number is 2737
# took 0.04498 minutes
# [INFO] Run Step number is 2738
# took 0.04587 minutes
# [INFO] Run Step number is 2739
# took 0.04529 minutes
# [INFO] Run Step number is 2740
# took 0.04606 minutes
# [INFO] test loss: 0.6992
# [INFO] Run Step number is 2741
# took 0.04765 minutes
# [INFO] Run Step number is 2742
# took 0.04429 minutes
# [INFO] Run Step number is 2743
# took 0.04576 minutes
# [INFO] Run Step number is 2744
# took 0.04587 minutes
# [INFO] Run Step number is 2745
# took 0.04405 minutes
# ...
